# %%
# !pip install torch torchvision matplotlib
# Out:
# Collecting torch
#   Downloading torch-2.11.0-cp313-cp313-win_amd64.whl.metadata (29 kB)
# Collecting torchvision
#   Downloading torchvision-0.26.0-cp313-cp313-win_amd64.whl.metadata (5.5 kB)
# Requirement already satisfied: matplotlib in c:\users\vishn\anaconda3\lib\site-packages (3.10.0)
# Requirement already satisfied: filelock in c:\users\vishn\anaconda3\lib\site-packages (from torch) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\vishn\appdata\roaming\python\python313\site-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools<82 in c:\users\vishn\anaconda3\lib\site-packages (from torch) (72.1.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\vishn\anaconda3\lib\site-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\vishn\anaconda3\lib\site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\vishn\anaconda3\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\vishn\anaconda3\lib\site-packages (from torch) (2025.3.2)
# Requirement already satisfied: numpy in c:\users\vishn\anaconda3\lib\site-packages (from torchvision) (2.1.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\vishn\anaconda3\lib\site-packages (from torchvision) (11.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\vishn\anaconda3\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\vishn\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\vishn\anaconda3\lib\site-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\vishn\anaconda3\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\vishn\anaconda3\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\vishn\anaconda3\lib\site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\vishn\anaconda3\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\vishn\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\vishn\anaconda3\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\vishn\anaconda3\lib\site-packages (from jinja2->torch) (3.0.2)
# Downloading torch-2.11.0-cp313-cp313-win_amd64.whl (114.6 MB)
#    ---------------------------------------- 0.0/114.6 MB ? eta -:--:--
#    ---------------------------------------- 0.5/114.6 MB 3.9 MB/s eta 0:00:30
#    - -------------------------------------- 3.4/114.6 MB 10.3 MB/s eta 0:00:11
#    - -------------------------------------- 5.2/114.6 MB 9.5 MB/s eta 0:00:12
#    --- ------------------------------------ 8.7/114.6 MB 11.4 MB/s eta 0:00:10
#    --- ------------------------------------ 11.3/114.6 MB 12.1 MB/s eta 0:00:09
#    ----- ---------------------------------- 14.4/114.6 MB 12.3 MB/s eta 0:00:09
#    ----- ---------------------------------- 17.0/114.6 MB 12.4 MB/s eta 0:00:08
#    ------ --------------------------------- 19.9/114.6 MB 12.7 MB/s eta 0:00:08
#    ------- -------------------------------- 22.5/114.6 MB 12.8 MB/s eta 0:00:08
#    -------- ------------------------------- 25.7/114.6 MB 13.0 MB/s eta 0:00:07
#    --------- ------------------------------ 28.6/114.6 MB 13.1 MB/s eta 0:00:07
#    ---------- ----------------------------- 31.5/114.6 MB 13.1 MB/s eta 0:00:07
#    ----------- ---------------------------- 34.3/114.6 MB 13.2 MB/s eta 0:00:07
#    ------------- -------------------------- 37.5/114.6 MB 13.2 MB/s eta 0:00:06
#    -------------- ------------------------- 40.4/114.6 MB 13.3 MB/s eta 0:00:06
#    --------------- ------------------------ 43.3/114.6 MB 13.4 MB/s eta 0:00:06
#    ---------------- ----------------------- 46.4/114.6 MB 13.4 MB/s eta 0:00:06
#    ----------------- ---------------------- 49.3/114.6 MB 13.5 MB/s eta 0:00:05
#    ------------------ --------------------- 51.9/114.6 MB 13.5 MB/s eta 0:00:05
#    ------------------- -------------------- 54.5/114.6 MB 13.4 MB/s eta 0:00:05
#    ------------------- -------------------- 56.6/114.6 MB 13.4 MB/s eta 0:00:05
#    -------------------- ------------------- 59.8/114.6 MB 13.3 MB/s eta 0:00:05
#    --------------------- ------------------ 62.4/114.6 MB 13.3 MB/s eta 0:00:04
#    ---------------------- ----------------- 65.3/114.6 MB 13.3 MB/s eta 0:00:04
#    ----------------------- ---------------- 68.2/114.6 MB 13.4 MB/s eta 0:00:04
#    ------------------------ --------------- 71.0/114.6 MB 13.4 MB/s eta 0:00:04
#    ------------------------- -------------- 73.9/114.6 MB 13.4 MB/s eta 0:00:04
#    -------------------------- ------------- 76.8/114.6 MB 13.5 MB/s eta 0:00:03
#    --------------------------- ------------ 79.7/114.6 MB 13.5 MB/s eta 0:00:03
#    ---------------------------- ----------- 82.8/114.6 MB 13.5 MB/s eta 0:00:03
#    ----------------------------- ---------- 85.5/114.6 MB 13.5 MB/s eta 0:00:03
#    ------------------------------ --------- 88.3/114.6 MB 13.5 MB/s eta 0:00:02
#    ------------------------------- -------- 91.2/114.6 MB 13.5 MB/s eta 0:00:02
#    -------------------------------- ------- 94.4/114.6 MB 13.6 MB/s eta 0:00:02
#    --------------------------------- ------ 97.0/114.6 MB 13.6 MB/s eta 0:00:02
#    ---------------------------------- ----- 99.9/114.6 MB 13.6 MB/s eta 0:00:02
#    ----------------------------------- --- 103.0/114.6 MB 13.6 MB/s eta 0:00:01
#    ------------------------------------ -- 105.9/114.6 MB 13.6 MB/s eta 0:00:01
#    ------------------------------------ -- 108.5/114.6 MB 13.6 MB/s eta 0:00:01
#    ------------------------------------- - 111.4/114.6 MB 13.6 MB/s eta 0:00:01
#    --------------------------------------  114.3/114.6 MB 13.6 MB/s eta 0:00:01
#    --------------------------------------  114.3/114.6 MB 13.6 MB/s eta 0:00:01
#    --------------------------------------  114.3/114.6 MB 13.6 MB/s eta 0:00:01
#    --------------------------------------  114.3/114.6 MB 13.6 MB/s eta 0:00:01
#    --------------------------------------  114.3/114.6 MB 13.6 MB/s eta 0:00:01
#    --------------------------------------  114.3/114.6 MB 13.6 MB/s eta 0:00:01
#    --------------------------------------- 114.6/114.6 MB 12.0 MB/s eta 0:00:00
# Downloading torchvision-0.26.0-cp313-cp313-win_amd64.whl (4.3 MB)
#    ---------------------------------------- 0.0/4.3 MB ? eta -:--:--
#    -------------------------- ------------- 2.9/4.3 MB 14.2 MB/s eta 0:00:01
#    ---------------------------------------- 4.3/4.3 MB 11.5 MB/s eta 0:00:00
# Installing collected packages: torch, torchvision
#
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    -------------------- ------------------- 1/2 [torchvision]
#    -------------------- ------------------- 1/2 [torchvision]
#    -------------------- ------------------- 1/2 [torchvision]
#    -------------------- ------------------- 1/2 [torchvision]
#    -------------------- ------------------- 1/2 [torchvision]
#    -------------------- ------------------- 1/2 [torchvision]
#    -------------------- ------------------- 1/2 [torchvision]
#    -------------------- ------------------- 1/2 [torchvision]
#    -------------------- ------------------- 1/2 [torchvision]
#    -------------------- ------------------- 1/2 [torchvision]
#    ---------------------------------------- 2/2 [torchvision]
#
# Successfully installed torch-2.11.0 torchvision-0.26.0

# %%
import torch
import matplotlib.pyplot as plt

from torchvision import datasets, transforms
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import torch
#       2 import matplotlib.pyplot as plt
#       4 from torchvision import datasets, transforms
#
# ModuleNotFoundError: No module named 'torch'
