# %% [markdown]
# <a href="https://colab.research.google.com/github/Vandanareddy2/mnist-digit-classifier/blob/main/notebook/01_tensor_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch

print(torch.__version__)
print(torch.cuda.is_available())
# Out:
# 2.10.0+cpu
# False
